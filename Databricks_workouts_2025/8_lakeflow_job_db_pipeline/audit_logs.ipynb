# %%
# %sql
select * from catalog3_we47.schema3_we47.audit_log;

# %%
# %sql
create table if not exists catalog3_we47.schema3_we47.audit_log(
  id bigint generated always as identity (start with 1 increment by 1),
  message string,
  loadts timestamp
)
using delta;

# %%
# %sql
insert into catalog3_we47.schema3_we47.audit_log(message,loadts) values('No data in the source table',current_timestamp);
