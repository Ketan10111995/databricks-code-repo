# %% [markdown]
# Task1: Document the Notebook Using mark down %md
# A good Title
# Description of the task
# Your name in some color
# Bring our Team photo from the given url "https://fpimages.withfloats.com/actual/6929d1ac956d0a744b5c9822.jpeg"
# Use headings, bold, italics appropriately.

# %% [markdown]
# # **Databricks Project Documentation**
#
# ## **Task Overview**
# **This notebook is designed to demonstrate Databricks fundamentals, including data ingestion, transformation, and visualization using Spark and Python.**
#
# ### 👤 Author
# <font color="blue"><b>Ketan Choudhary</b></font>

# %% [markdown]
# # _**Databricks Project Documentation**_
# ## _Task Overview_
# This notebook is been setup for completing the multiple usecases
#
# ### <span style="colour:blue;">Ketan Choudhary</span>
#
# <img src="https://fpimages.withfloats.com/actual/6929d1ac956d0a744b5c9822.jpeg" width="600"/>

# %%
# %sql
CREATE VOLUME usage_metrics;

# %%
import requests
data=requests.get("https://public.tableau.com/app/sample-data/mobile_os_usage.csv")
dbutils.fs.put("/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv",data.text,overwrite=True)

# %%
# %run 
"/Workspace/Users/ketanchoudhary1011@gmail.com/NoteBook/Databricks_Notebook_Fundamental/4_child_notebook"

# %%
files = dbutils.fs.ls("/Volumes/workspace/default/usage_metrics")
display(files)
# %fs head /Volumes/workspace/default/usage_metrics/mobile_os_usage.csv

# %%
df1 = spark.read.csv("/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv", header=True)
print(df1.is_cached)
df2=df1.repartition(4)
display(df2)

# %%
df2.write.mode("overwrite").saveAsTable("default.cities")

# %%
df = spark.sql("SELECT * FROM default.cities")
display(df)

# %%
dbutils.widgets.text("input_text", "Enter text")
input_text = dbutils.widgets.get("input_text")

def to_uppercase(text):
    return text.upper()

upper_text = to_uppercase(input_text)
display(input_text)
display(upper_text)

# %%
# %pip install pandas

# %%
import pandas as pd

df_pd = None
try:
    df_pd = pd.read_csv(
        "/dbfs/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv"
    )
except OSError as e:
    print(f"Error reading CSV file: {e}")

if df_pd is not None:
    display(df_pd)

# %%
# %sh
echo "Magic commands tasks completed"
