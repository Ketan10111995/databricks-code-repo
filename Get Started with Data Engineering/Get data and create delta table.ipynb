# %%
current_catalog = spark.sql("SELECT current_catalog()").collect() 
current_schema = spark.sql("SELECT current_schema()").collect()

print(f"Catalog: {current_catalog}")
print(f"Schema:  {current_schema}")

# %%
# %sql
USE CATALOG ketancatalog;
USE SCHEMA ketanschema;
SELECT current_catalog(), current_schema();

# %%
# %sql
SELECT * FROM read_files('/Volumes/ketancatalog/ketanschema/myfiles/employees.csv');

-- df=spark.read.csv("/Volumes/ketancatalog/ketanschema/myfiles/employees.csv",header=True,inferSchema=True)
-- df.show()

--  a new column called _rescued_data with null values. Databricks automatically adds this column when reading files — if any rows don't conform to the inferred schema (wrong data types, extra fields, malformed records), those values are captured here

# %%
df.write.saveAsTable("ketancatalog.ketanschema.employees", mode="overwrite")

# %%
# %sql
CREATE TABLE IF NOT EXISTS employees
AS SELECT * FROM read_files('/Volumes/ketancatalog/ketanschema/myfiles/employees.csv');

# %%
# %sql
select * from ketancatalog.ketanschema.employees;
